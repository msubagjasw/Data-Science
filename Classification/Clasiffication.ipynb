# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
# %matplotlib inline
import numpy as np

# %%
df_claim = pd.read_csv('https://raw.githubusercontent.com/apischdo/skillsacademy/master/AutoInsClaims.csv')

# %%
class BasicInfo:
    ''' Just insert dataframe and show all basic information, for running execute 
    BasicInfo(your df).all_call()'''
    
    def __init__(self, df):
        self.df = df
    def heads(self):
        display(self.df.head())
    def shape(self):
        print('Shape of Dataframe :')
        print(self.df.shape)
        print()
    def cols(self):
        print('Columns of Dataframe :')
        print(self.df.columns)
        print()
    def typess(self):
        print('Types information of Data Frame :')
        display(self.df.dtypes.to_frame())
        print()
    def describe(self):
        print('Descriptive Statistic of Dataframe :')
        display(self.df.describe(include='all'))
        print()
    def correlation_plot(self):
        print('Correlation Heatmap :')
        display(sns.heatmap(self.df.corr()))
        print()
    def correlation(self):
        print('Correlation :')
        display(self.df.corr())
        print()
    def isna(self):
        print('Null information :')
        display(self.df.isnull().sum().to_frame())
        print()
    def plot_isna(self):
        print('Plotting Null :')
        #display(sns.heatmap(self.df.isnull(), cbar=False))
        display(msno.matrix(self.df))
        print()
    def all_call(self):
        self.heads()
        self.shape()
        self.cols()
        self.typess()
        self.describe()
        self.correlation_plot()
        self.correlation()
        self.isna()
        self.plot_isna()

# %%
info = BasicInfo(df_claim).all_call()
info
# Out:
#   HOUSEHOLD_ID DRIVER_ID  POLICY_ID      CLAIM_ID  INCIDENT_CAUSE  \
# 0      CH42335   XZJ2837  NW5567882  A-2017-UU907               3
# 1      IH49805   VVR6423  UR4864804  A-2018-FI481               3
# 2      AF28736   UQM2512  RR8595908  A-2016-ZG694               1
# 3      EF53594   YDT5591  RN5640634  A-2016-NG783               1
# 4      LD32277   ONM5465  YY1229530  A-2017-ZO863               3
#
#    DESCRIPTION  CLAIM_STATUS  ODOMETER_AT_LOSS LOSS_EVENT_TIME  \
# 0          NaN             1          157654.9         4/25/17
# 1          NaN             3          226154.5         8/26/18
# 2          NaN             1           83968.6          1/7/16
# 3          NaN             1          309570.3        12/11/16
# 4          NaN             3          136633.9          6/6/17
#
#   CLAIM_INIT_TIME  POLICE_REPORT  CLAIMS_AT_LOSS_DATE  LOSS_LOCATION_LAT  \
# 0         4/28/17              1                    1          41.902103
# 1         8/31/18              0                    1          41.963562
# 2         1/11/16              0                    2          41.736602
# 3        12/18/16              0                    1          41.909925
# 4          6/8/17              0                    1          41.923750
#
#    LOSS_LOCATION_LONG  CLAIM_AMOUNT  FLAG_FOR_FRAUD_INV PRIMARY_DRIVER_ID  \
# 0          -87.755624       35765.0                   1           XZJ2837
# 1          -87.731397        1909.0                   0           VVR6423
# 2          -87.604968       25730.0                   1           UQM2512
# 3          -87.731557       40880.0                   1           YDT5591
# 4          -87.789881        2130.0                   0           JZZ5688
#
#   START_DATE EXPIRY_DATE  MODEL_YEAR       MAKE    MODEL    PLATE   COLOR  \
# 0    9/19/16     9/19/17        2010     Nissan   Sentra  MJCW106  Silver
# 1    6/14/17     6/14/18        2008      Dodge      Ram  LKUD688   White
# 2    8/24/15     8/23/16        2009  Chevrolet  Equinox  OBQU415   White
# 3    7/25/15     7/24/16        2002  Chevrolet  Equinox  EVOQ882   White
# 4     1/8/16      1/7/17        2010      Honda     CR-V  OGDM932   White
#
#    INITIAL_ODOMETER  LOW_MILEAGE_USE FIRST_NAME LAST_NAME GENDER BIRTHDATE  \
# 0            144972                0       Will     Dorau      M  12/25/73
# 1            212580                0     Tammie   Mostrom      F   9/14/45
# 2             77994                1     Esther  Sebranek      F   5/16/88
# 3            296352                0      Donny  Nickless      M   1/18/74
# 4            134244                0      Floyd    Liggan      M    5/1/50
#
#            SSN DRIVERS_LICENSE_ID DRIVERS_LICENSE_EXPIRY  \
# 0  457-20-9007     X151-5971-1594                8/19/18
# 1  718-38-8987     K702-7678-1851                1/27/18
# 2  076-62-7083     V549-5272-3181               11/19/19
# 3  571-32-3662     Z350-2956-6553                5/16/19
# 4  315-84-4443     E912-8544-3880                 7/6/20
#
#   DRIVERS_LICENSE_STATE DATE_AT_CURRENT_ADDRESS CONTACT_NUMBER  \
# 0                    IL                 4/16/99  634-603-0960
# 1                    IL                  6/9/11  827-916-0381
# 2                    IL                 5/21/05  723-552-0479
# 3                    IL                 3/11/00  741-637-0631
# 4                    IL                  7/4/12  735-427-0152
#
#                    EMAIL  COMMUTE_DISCOUNT
# 0  wdorau@freshmaail.com                 0
# 1    tmostrom@yahoot.com                 0
# 2    esebranek@zohoo.com                 0
# 3     dnickless@life.com                 0
# 4   fliggan@mooosend.com                 0
# Shape of Dataframe :
# (975, 38)
#
# Columns of Dataframe :
# Index(['HOUSEHOLD_ID', 'DRIVER_ID', 'POLICY_ID', 'CLAIM_ID', 'INCIDENT_CAUSE',
#        'DESCRIPTION', 'CLAIM_STATUS', 'ODOMETER_AT_LOSS', 'LOSS_EVENT_TIME',
#        'CLAIM_INIT_TIME', 'POLICE_REPORT', 'CLAIMS_AT_LOSS_DATE',
#        'LOSS_LOCATION_LAT', 'LOSS_LOCATION_LONG', 'CLAIM_AMOUNT',
#        'FLAG_FOR_FRAUD_INV', 'PRIMARY_DRIVER_ID', 'START_DATE', 'EXPIRY_DATE',
#        'MODEL_YEAR', 'MAKE', 'MODEL', 'PLATE', 'COLOR', 'INITIAL_ODOMETER',
#        'LOW_MILEAGE_USE', 'FIRST_NAME', 'LAST_NAME', 'GENDER', 'BIRTHDATE',
#        'SSN', 'DRIVERS_LICENSE_ID', 'DRIVERS_LICENSE_EXPIRY',
#        'DRIVERS_LICENSE_STATE', 'DATE_AT_CURRENT_ADDRESS', 'CONTACT_NUMBER',
#        'EMAIL', 'COMMUTE_DISCOUNT'],
#       dtype='object')
#
# Types information of Data Frame :
#                                0
# HOUSEHOLD_ID              object
# DRIVER_ID                 object
# POLICY_ID                 object
# CLAIM_ID                  object
# INCIDENT_CAUSE             int64
# DESCRIPTION              float64
# CLAIM_STATUS               int64
# ODOMETER_AT_LOSS         float64
# LOSS_EVENT_TIME           object
# CLAIM_INIT_TIME           object
# POLICE_REPORT              int64
# CLAIMS_AT_LOSS_DATE        int64
# LOSS_LOCATION_LAT        float64
# LOSS_LOCATION_LONG       float64
# CLAIM_AMOUNT             float64
# FLAG_FOR_FRAUD_INV         int64
# PRIMARY_DRIVER_ID         object
# START_DATE                object
# EXPIRY_DATE               object
# MODEL_YEAR                 int64
# MAKE                      object
# MODEL                     object
# PLATE                     object
# COLOR                     object
# INITIAL_ODOMETER           int64
# LOW_MILEAGE_USE            int64
# FIRST_NAME                object
# LAST_NAME                 object
# GENDER                    object
# BIRTHDATE                 object
# SSN                       object
# DRIVERS_LICENSE_ID        object
# DRIVERS_LICENSE_EXPIRY    object
# DRIVERS_LICENSE_STATE     object
# DATE_AT_CURRENT_ADDRESS   object
# CONTACT_NUMBER            object
# EMAIL                     object
# COMMUTE_DISCOUNT           int64
# Descriptive Statistic of Dataframe :
#        HOUSEHOLD_ID DRIVER_ID  POLICY_ID      CLAIM_ID  INCIDENT_CAUSE  \
# count           975       975        975           975      975.000000
# unique          975       975        975           975             NaN
# top         DM94144   PUS7822  NN4080926  A-2016-BS440             NaN
# freq              1         1          1             1             NaN
# mean            NaN       NaN        NaN           NaN        2.974359
# std             NaN       NaN        NaN           NaN        1.503029
# min             NaN       NaN        NaN           NaN        1.000000
# 25%             NaN       NaN        NaN           NaN        2.000000
# 50%             NaN       NaN        NaN           NaN        3.000000
# 75%             NaN       NaN        NaN           NaN        5.000000
# max             NaN       NaN        NaN           NaN        5.000000
#
#         DESCRIPTION  CLAIM_STATUS  ODOMETER_AT_LOSS LOSS_EVENT_TIME  \
# count           0.0    975.000000        975.000000             975
# unique          NaN           NaN               NaN             665
# top             NaN           NaN               NaN         7/12/18
# freq            NaN           NaN               NaN               5
# mean            NaN      2.196923     178585.283282             NaN
# std             NaN      0.995983      99500.258502             NaN
# min             NaN      1.000000      21015.800000             NaN
# 25%             NaN      1.000000      99356.900000             NaN
# 50%             NaN      3.000000     163689.500000             NaN
# 75%             NaN      3.000000     238025.200000             NaN
# max             NaN      4.000000     593427.400000             NaN
#
#        CLAIM_INIT_TIME  POLICE_REPORT  CLAIMS_AT_LOSS_DATE  LOSS_LOCATION_LAT  \
# count              975     975.000000           975.000000         975.000000
# unique             655            NaN                  NaN                NaN
# top             3/9/16            NaN                  NaN                NaN
# freq                 5            NaN                  NaN                NaN
# mean               NaN       0.429744             1.603077          41.858827
# std                NaN       0.495293             1.155022           0.085914
# min                NaN       0.000000             1.000000          41.651701
# 25%                NaN       0.000000             1.000000          41.783034
# 50%                NaN       0.000000             1.000000          41.874328
# 75%                NaN       1.000000             2.000000          41.923888
# max                NaN       1.000000             8.000000          42.021691
#
#         LOSS_LOCATION_LONG  CLAIM_AMOUNT  FLAG_FOR_FRAUD_INV  \
# count           975.000000    975.000000          975.000000
# unique                 NaN           NaN                 NaN
# top                    NaN           NaN                 NaN
# freq                   NaN           NaN                 NaN
# mean            -87.676931  12476.822564            0.416410
# std               0.058369  13697.986713            0.493216
# min             -87.905309   1000.000000            0.000000
# 25%             -87.720619   1900.000000            0.000000
# 50%             -87.673203   2780.000000            0.000000
# 75%             -87.631030  24300.000000            1.000000
# max             -87.527492  48035.500000            1.000000
#
#        PRIMARY_DRIVER_ID START_DATE EXPIRY_DATE   MODEL_YEAR       MAKE  \
# count                975        975         975   975.000000        975
# unique               975        595         595          NaN         21
# top              PUS7822    7/12/15     7/11/16          NaN  Chevrolet
# freq                   1          7           7          NaN        138
# mean                 NaN        NaN         NaN  2008.503590        NaN
# std                  NaN        NaN         NaN     4.701537        NaN
# min                  NaN        NaN         NaN  1991.000000        NaN
# 25%                  NaN        NaN         NaN  2006.000000        NaN
# 50%                  NaN        NaN         NaN  2009.000000        NaN
# 75%                  NaN        NaN         NaN  2012.000000        NaN
# max                  NaN        NaN         NaN  2016.000000        NaN
#
#         MODEL    PLATE   COLOR  INITIAL_ODOMETER  LOW_MILEAGE_USE FIRST_NAME  \
# count     975      975     975        975.000000       975.000000        975
# unique    100      975      10               NaN              NaN        783
# top     F-150  RMJV864  Silver               NaN              NaN    Felicia
# freq       42        1     268               NaN              NaN          4
# mean      NaN      NaN     NaN     170987.852308         0.092308        NaN
# std       NaN      NaN     NaN      99443.427598         0.289608        NaN
# min       NaN      NaN     NaN      18348.000000         0.000000        NaN
# 25%       NaN      NaN     NaN      92310.000000         0.000000        NaN
# 50%       NaN      NaN     NaN     155652.000000         0.000000        NaN
# 75%       NaN      NaN     NaN     230514.000000         0.000000        NaN
# max       NaN      NaN     NaN     585828.000000         1.000000        NaN
#
#        LAST_NAME GENDER BIRTHDATE          SSN DRIVERS_LICENSE_ID  \
# count        975    975       975          975                975
# unique       974      2       955          975                975
# top        Tobal      M  11/16/73  257-68-7954     Z266-2079-9402
# freq           2    493         2            1                  1
# mean         NaN    NaN       NaN          NaN                NaN
# std          NaN    NaN       NaN          NaN                NaN
# min          NaN    NaN       NaN          NaN                NaN
# 25%          NaN    NaN       NaN          NaN                NaN
# 50%          NaN    NaN       NaN          NaN                NaN
# 75%          NaN    NaN       NaN          NaN                NaN
# max          NaN    NaN       NaN          NaN                NaN
#
#        DRIVERS_LICENSE_EXPIRY DRIVERS_LICENSE_STATE DATE_AT_CURRENT_ADDRESS  \
# count                     975                   975                     975
# unique                    720                     1                     891
# top                    7/9/18                    IL                11/19/06
# freq                        6                   975                       3
# mean                      NaN                   NaN                     NaN
# std                       NaN                   NaN                     NaN
# min                       NaN                   NaN                     NaN
# 25%                       NaN                   NaN                     NaN
# 50%                       NaN                   NaN                     NaN
# 75%                       NaN                   NaN                     NaN
# max                       NaN                   NaN                     NaN
#
#        CONTACT_NUMBER                    EMAIL  COMMUTE_DISCOUNT
# count             975                      975        975.000000
# unique            975                      975               NaN
# top     750-390-0379   dadelberg@husshmail.com               NaN
# freq                1                        1               NaN
# mean              NaN                      NaN          0.060513
# std               NaN                      NaN          0.238557
# min               NaN                      NaN          0.000000
# 25%               NaN                      NaN          0.000000
# 50%               NaN                      NaN          0.000000
# 75%               NaN                      NaN          0.000000
# max               NaN                      NaN          1.000000
# Correlation Heatmap :
# Correlation :
#                      INCIDENT_CAUSE  DESCRIPTION  CLAIM_STATUS  \
# INCIDENT_CAUSE             1.000000          NaN     -0.026115
# DESCRIPTION                     NaN          NaN           NaN
# CLAIM_STATUS              -0.026115          NaN      1.000000
# ODOMETER_AT_LOSS          -0.003935          NaN      0.013058
# POLICE_REPORT              0.101703          NaN     -0.327821
# CLAIMS_AT_LOSS_DATE       -0.006460          NaN     -0.114943
# LOSS_LOCATION_LAT          0.025496          NaN     -0.015531
# LOSS_LOCATION_LONG        -0.027283          NaN      0.028557
# CLAIM_AMOUNT               0.045416          NaN     -0.792106
# FLAG_FOR_FRAUD_INV         0.037962          NaN     -0.927869
# MODEL_YEAR                -0.009213          NaN     -0.016157
# INITIAL_ODOMETER          -0.002082          NaN      0.012986
# LOW_MILEAGE_USE            0.017236          NaN      0.008105
# COMMUTE_DISCOUNT          -0.012849          NaN      0.044860
#
#                      ODOMETER_AT_LOSS  POLICE_REPORT  CLAIMS_AT_LOSS_DATE  \
# INCIDENT_CAUSE              -0.003935       0.101703            -0.006460
# DESCRIPTION                       NaN            NaN                  NaN
# CLAIM_STATUS                 0.013058      -0.327821            -0.114943
# ODOMETER_AT_LOSS             1.000000      -0.032422             0.032294
# POLICE_REPORT               -0.032422       1.000000            -0.008416
# CLAIMS_AT_LOSS_DATE          0.032294      -0.008416             1.000000
# LOSS_LOCATION_LAT           -0.042848       0.014111             0.006126
# LOSS_LOCATION_LONG           0.021150      -0.055266             0.013027
# CLAIM_AMOUNT                -0.008896       0.359954            -0.003875
# FLAG_FOR_FRAUD_INV          -0.026172       0.355240             0.113813
# MODEL_YEAR                  -0.921606       0.025129            -0.037456
# INITIAL_ODOMETER             0.999135      -0.029939             0.033227
# LOW_MILEAGE_USE             -0.267947       0.009470            -0.010058
# COMMUTE_DISCOUNT            -0.043781      -0.037841             0.035094
#
#                      LOSS_LOCATION_LAT  LOSS_LOCATION_LONG  CLAIM_AMOUNT  \
# INCIDENT_CAUSE                0.025496           -0.027283      0.045416
# DESCRIPTION                        NaN                 NaN           NaN
# CLAIM_STATUS                 -0.015531            0.028557     -0.792106
# ODOMETER_AT_LOSS             -0.042848            0.021150     -0.008896
# POLICE_REPORT                 0.014111           -0.055266      0.359954
# CLAIMS_AT_LOSS_DATE           0.006126            0.013027     -0.003875
# LOSS_LOCATION_LAT             1.000000           -0.444442     -0.000063
# LOSS_LOCATION_LONG           -0.444442            1.000000     -0.035604
# CLAIM_AMOUNT                 -0.000063           -0.035604      1.000000
# FLAG_FOR_FRAUD_INV            0.012848           -0.038900      0.860855
# MODEL_YEAR                    0.044275           -0.014467      0.014718
# INITIAL_ODOMETER             -0.042686            0.021064     -0.008215
# LOW_MILEAGE_USE               0.024678           -0.042753      0.007224
# COMMUTE_DISCOUNT             -0.004843            0.042759     -0.026906
#
#                      FLAG_FOR_FRAUD_INV  MODEL_YEAR  INITIAL_ODOMETER  \
# INCIDENT_CAUSE                 0.037962   -0.009213         -0.002082
# DESCRIPTION                         NaN         NaN               NaN
# CLAIM_STATUS                  -0.927869   -0.016157          0.012986
# ODOMETER_AT_LOSS              -0.026172   -0.921606          0.999135
# POLICE_REPORT                  0.355240    0.025129         -0.029939
# CLAIMS_AT_LOSS_DATE            0.113813   -0.037456          0.033227
# LOSS_LOCATION_LAT              0.012848    0.044275         -0.042686
# LOSS_LOCATION_LONG            -0.038900   -0.014467          0.021064
# CLAIM_AMOUNT                   0.860855    0.014718         -0.008215
# FLAG_FOR_FRAUD_INV             1.000000    0.034775         -0.025499
# MODEL_YEAR                     0.034775    1.000000         -0.922633
# INITIAL_ODOMETER              -0.025499   -0.922633          1.000000
# LOW_MILEAGE_USE               -0.010616   -0.014570         -0.266867
# COMMUTE_DISCOUNT              -0.039862    0.034133         -0.042275
#
#                      LOW_MILEAGE_USE  COMMUTE_DISCOUNT
# INCIDENT_CAUSE              0.017236         -0.012849
# DESCRIPTION                      NaN               NaN
# CLAIM_STATUS                0.008105          0.044860
# ODOMETER_AT_LOSS           -0.267947         -0.043781
# POLICE_REPORT               0.009470         -0.037841
# CLAIMS_AT_LOSS_DATE        -0.010058          0.035094
# LOSS_LOCATION_LAT           0.024678         -0.004843
# LOSS_LOCATION_LONG         -0.042753          0.042759
# CLAIM_AMOUNT                0.007224         -0.026906
# FLAG_FOR_FRAUD_INV         -0.010616         -0.039862
# MODEL_YEAR                 -0.014570          0.034133
# INITIAL_ODOMETER           -0.266867         -0.042275
# LOW_MILEAGE_USE             1.000000          0.008231
# COMMUTE_DISCOUNT            0.008231          1.000000
# Null information :
#                            0
# HOUSEHOLD_ID               0
# DRIVER_ID                  0
# POLICY_ID                  0
# CLAIM_ID                   0
# INCIDENT_CAUSE             0
# DESCRIPTION              975
# CLAIM_STATUS               0
# ODOMETER_AT_LOSS           0
# LOSS_EVENT_TIME            0
# CLAIM_INIT_TIME            0
# POLICE_REPORT              0
# CLAIMS_AT_LOSS_DATE        0
# LOSS_LOCATION_LAT          0
# LOSS_LOCATION_LONG         0
# CLAIM_AMOUNT               0
# FLAG_FOR_FRAUD_INV         0
# PRIMARY_DRIVER_ID          0
# START_DATE                 0
# EXPIRY_DATE                0
# MODEL_YEAR                 0
# MAKE                       0
# MODEL                      0
# PLATE                      0
# COLOR                      0
# INITIAL_ODOMETER           0
# LOW_MILEAGE_USE            0
# FIRST_NAME                 0
# LAST_NAME                  0
# GENDER                     0
# BIRTHDATE                  0
# SSN                        0
# DRIVERS_LICENSE_ID         0
# DRIVERS_LICENSE_EXPIRY     0
# DRIVERS_LICENSE_STATE      0
# DATE_AT_CURRENT_ADDRESS    0
# CONTACT_NUMBER             0
# EMAIL                      0
# COMMUTE_DISCOUNT           0
# Plotting Null :

# %%
df_claim.DRIVERS_LICENSE_STATE.value_counts()
# Out:
# IL    975
# Name: DRIVERS_LICENSE_STATE, dtype: int64

# %% [markdown]
# so there is 38 columns, 975 rows, description id with full null rows, some basic information will be removed (license id, first name, last name, email, contact, state, household), and wrong data type several columns.

# %%
df_claim.CLAIM_ID.value_counts()
# Out:
# A-2016-BS440    1
# A-2017-PY923    1
# A-2018-DM603    1
# A-2018-OG581    1
# A-2017-DX139    1
#                ..
# A-2017-BX118    1
# A-2018-FV162    1
# A-2016-JH676    1
# A-2017-HE724    1
# A-2017-QY946    1
# Name: CLAIM_ID, Length: 975, dtype: int64

# %%
#Lets drop id columns and null columns!
df_claim.drop(columns=['HOUSEHOLD_ID', 'DRIVER_ID', 'POLICY_ID', 'POLICY_ID', 'CLAIM_ID', 'DESCRIPTION',\
                       'PRIMARY_DRIVER_ID', 'PLATE', 'FIRST_NAME', 'LAST_NAME', 'SSN', 'DRIVERS_LICENSE_ID',\
                      'DRIVERS_LICENSE_STATE', 'CONTACT_NUMBER', 'EMAIL'], inplace=True)
df_claim
# Out:
#      INCIDENT_CAUSE  CLAIM_STATUS  ODOMETER_AT_LOSS LOSS_EVENT_TIME  \
# 0                 3             1          157654.9         4/25/17
# 1                 3             3          226154.5         8/26/18
# 2                 1             1           83968.6          1/7/16
# 3                 1             1          309570.3        12/11/16
# 4                 3             3          136633.9          6/6/17
# ..              ...           ...               ...             ...
# 970               3             1           77438.7        11/29/16
# 971               1             3          219285.9         8/14/16
# 972               1             1          192320.1         8/22/16
# 973               2             3          273023.9         1/24/17
# 974               2             3          178004.2          7/5/16
#
#     CLAIM_INIT_TIME  POLICE_REPORT  CLAIMS_AT_LOSS_DATE  LOSS_LOCATION_LAT  \
# 0           4/28/17              1                    1          41.902103
# 1           8/31/18              0                    1          41.963562
# 2           1/11/16              0                    2          41.736602
# 3          12/18/16              0                    1          41.909925
# 4            6/8/17              0                    1          41.923750
# ..              ...            ...                  ...                ...
# 970         12/1/16              1                    1          41.876984
# 971         8/21/16              0                    1          42.002596
# 972          9/3/16              1                    1          41.778640
# 973          2/4/17              0                    1          41.770738
# 974          7/9/16              1                    1          41.768244
#
#      LOSS_LOCATION_LONG  CLAIM_AMOUNT  FLAG_FOR_FRAUD_INV START_DATE  \
# 0            -87.755624       35765.0                   1    9/19/16
# 1            -87.731397        1909.0                   0    6/14/17
# 2            -87.604968       25730.0                   1    8/24/15
# 3            -87.731557       40880.0                   1    7/25/15
# 4            -87.789881        2130.0                   0     1/8/16
# ..                  ...           ...                 ...        ...
# 970          -87.742824       44666.0                   1    7/12/15
# 971          -87.660932        2320.0                   0    7/21/15
# 972          -87.722613       39307.0                   1    8/21/15
# 973          -87.722707        1720.0                   0    4/21/16
# 974          -87.619856        1050.0                   0    1/10/15
#
#     EXPIRY_DATE  MODEL_YEAR        MAKE     MODEL           COLOR  \
# 0       9/19/17        2010      Nissan    Sentra          Silver
# 1       6/14/18        2008       Dodge       Ram           White
# 2       8/23/16        2009   Chevrolet   Equinox           White
# 3       7/24/16        2002   Chevrolet   Equinox           White
# 4        1/7/17        2010       Honda      CR-V           White
# ..          ...         ...         ...       ...             ...
# 970     7/11/16        2013  Volkswagen     Jetta          Silver
# 971     7/20/16        2007     Hyundai  Santa Fe          Silver
# 972     8/20/16        2006   Chevrolet     Tahoe         Med Red
# 973     4/21/17        2003      Toyota     Camry          Silver
# 974     1/10/16        2007        Ford     F-150  Med. Dark Gray
#
#      INITIAL_ODOMETER  LOW_MILEAGE_USE GENDER BIRTHDATE  \
# 0              144972                0      M  12/25/73
# 1              212580                0      F   9/14/45
# 2               77994                1      F   5/16/88
# 3              296352                0      M   1/18/74
# 4              134244                0      M    5/1/50
# ..                ...              ...    ...       ...
# 970             70416                0      F  11/10/79
# 971            213624                0      M    2/1/69
# 972            187680                0      M   9/21/55
# 973            267060                0      M  10/25/69
# 974            164268                0      M    6/6/82
#
#     DRIVERS_LICENSE_EXPIRY DATE_AT_CURRENT_ADDRESS  COMMUTE_DISCOUNT
# 0                  8/19/18                 4/16/99                 0
# 1                  1/27/18                  6/9/11                 0
# 2                 11/19/19                 5/21/05                 0
# 3                  5/16/19                 3/11/00                 0
# 4                   7/6/20                  7/4/12                 0
# ..                     ...                     ...               ...
# 970                6/23/18                 6/21/15                 0
# 971                8/16/19                 5/11/14                 0
# 972               12/24/19                 1/14/14                 1
# 973                9/17/20                 2/11/10                 0
# 974                7/22/20                 9/12/03                 0
#
# [975 rows x 24 columns]

# %%
#Correcting Data type
#Convert into date
date_cols = ['LOSS_EVENT_TIME', 'CLAIM_INIT_TIME', 'START_DATE', 'EXPIRY_DATE', 'BIRTHDATE',\
             'DRIVERS_LICENSE_EXPIRY', 'DATE_AT_CURRENT_ADDRESS']

# %%
#Checking all date
df_claim[date_cols].dtypes
# Out:
# LOSS_EVENT_TIME            object
# CLAIM_INIT_TIME            object
# START_DATE                 object
# EXPIRY_DATE                object
# BIRTHDATE                  object
# DRIVERS_LICENSE_EXPIRY     object
# DATE_AT_CURRENT_ADDRESS    object
# dtype: object

# %%
for cols in date_cols:
    df_claim[cols]=pd.to_datetime(df_claim[cols])

# %%
#result
df_claim[date_cols].dtypes
# Out:
# LOSS_EVENT_TIME            datetime64[ns]
# CLAIM_INIT_TIME            datetime64[ns]
# START_DATE                 datetime64[ns]
# EXPIRY_DATE                datetime64[ns]
# BIRTHDATE                  datetime64[ns]
# DRIVERS_LICENSE_EXPIRY     datetime64[ns]
# DATE_AT_CURRENT_ADDRESS    datetime64[ns]
# dtype: object

# %%
df_claim.head()
# Out:
#    INCIDENT_CAUSE  CLAIM_STATUS  ODOMETER_AT_LOSS LOSS_EVENT_TIME  \
# 0               3             1          157654.9      2017-04-25
# 1               3             3          226154.5      2018-08-26
# 2               1             1           83968.6      2016-01-07
# 3               1             1          309570.3      2016-12-11
# 4               3             3          136633.9      2017-06-06
#
#   CLAIM_INIT_TIME  POLICE_REPORT  CLAIMS_AT_LOSS_DATE  LOSS_LOCATION_LAT  \
# 0      2017-04-28              1                    1          41.902103
# 1      2018-08-31              0                    1          41.963562
# 2      2016-01-11              0                    2          41.736602
# 3      2016-12-18              0                    1          41.909925
# 4      2017-06-08              0                    1          41.923750
#
#    LOSS_LOCATION_LONG  CLAIM_AMOUNT  FLAG_FOR_FRAUD_INV START_DATE  \
# 0          -87.755624       35765.0                   1 2016-09-19
# 1          -87.731397        1909.0                   0 2017-06-14
# 2          -87.604968       25730.0                   1 2015-08-24
# 3          -87.731557       40880.0                   1 2015-07-25
# 4          -87.789881        2130.0                   0 2016-01-08
#
#   EXPIRY_DATE  MODEL_YEAR       MAKE    MODEL   COLOR  INITIAL_ODOMETER  \
# 0  2017-09-19        2010     Nissan   Sentra  Silver            144972
# 1  2018-06-14        2008      Dodge      Ram   White            212580
# 2  2016-08-23        2009  Chevrolet  Equinox   White             77994
# 3  2016-07-24        2002  Chevrolet  Equinox   White            296352
# 4  2017-01-07        2010      Honda     CR-V   White            134244
#
#    LOW_MILEAGE_USE GENDER  BIRTHDATE DRIVERS_LICENSE_EXPIRY  \
# 0                0      M 1973-12-25             2018-08-19
# 1                0      F 2045-09-14             2018-01-27
# 2                1      F 1988-05-16             2019-11-19
# 3                0      M 1974-01-18             2019-05-16
# 4                0      M 2050-05-01             2020-07-06
#
#   DATE_AT_CURRENT_ADDRESS  COMMUTE_DISCOUNT
# 0              1999-04-16                 0
# 1              2011-06-09                 0
# 2              2005-05-21                 0
# 3              2000-03-11                 0
# 4              2012-07-04                 0

# %%
#Export to csv
df_claim.to_csv('claim.csv')

# %%
df_claim[['DRIVERS_LICENSE_EXPIRY', 'LOSS_EVENT_TIME']].head()
# Out:
#   DRIVERS_LICENSE_EXPIRY LOSS_EVENT_TIME
# 0             2018-08-19      2017-04-25
# 1             2018-01-27      2018-08-26
# 2             2019-11-19      2016-01-07
# 3             2019-05-16      2016-12-11
# 4             2020-07-06      2017-06-06

# %%
df_claim['LICENSE_LOSS'] = (df_claim.DRIVERS_LICENSE_EXPIRY - df_claim.LOSS_EVENT_TIME).dt.days
df_claim['LICENSE_LOSS']
# Out:
# 0       481
# 1      -211
# 2      1412
# 3       886
# 4      1126
#        ...
# 970     571
# 971    1097
# 972    1219
# 973    1332
# 974    1478
# Name: LICENSE_LOSS, Length: 975, dtype: int64

# %%
df_claim.rename(columns={'LICENSE_LOSS':'EXPIRED_LICENSE'}, inplace=True)

# %%
df_claim[['EXPIRY_DATE','LOSS_EVENT_TIME']].head()
# Out:
#   EXPIRY_DATE LOSS_EVENT_TIME
# 0  2017-09-19      2017-04-25
# 1  2018-06-14      2018-08-26
# 2  2016-08-23      2016-01-07
# 3  2016-07-24      2016-12-11
# 4  2017-01-07      2017-06-06

# %%
df_claim['EXPIRED_CLAIM'] = (df_claim.EXPIRY_DATE - df_claim.LOSS_EVENT_TIME).dt.days
df_claim['EXPIRED_CLAIM'].head(10)
# Out:
# 0    147
# 1    -73
# 2    229
# 3   -140
# 4   -150
# 5    -50
# 6    -36
# 7    182
# 8    239
# 9   -189
# Name: EXPIRED_CLAIM, dtype: int64

# %%
#check expired claim vs loss > 365 days
(df_claim['EXPIRED_CLAIM'] > 365).value_counts()
# Out:
# False    975
# Name: EXPIRED_CLAIM, dtype: int64

# %%
#a half customer claim issurance even expired!
(df_claim['EXPIRED_CLAIM'] < 0).value_counts()
# Out:
# True     510
# False    465
# Name: EXPIRED_CLAIM, dtype: int64

# %%
pd.DataFrame({'Columns ': df_claim.columns,"Unique" :[len(df_claim[unik].unique()) for unik in df_claim.columns]})
# Out:
#                    Columns   Unique
# 0            INCIDENT_CAUSE       5
# 1              CLAIM_STATUS       4
# 2          ODOMETER_AT_LOSS     975
# 3           LOSS_EVENT_TIME     665
# 4           CLAIM_INIT_TIME     655
# 5             POLICE_REPORT       2
# 6       CLAIMS_AT_LOSS_DATE       8
# 7         LOSS_LOCATION_LAT     959
# 8        LOSS_LOCATION_LONG     959
# 9              CLAIM_AMOUNT     656
# 10       FLAG_FOR_FRAUD_INV       2
# 11               START_DATE     595
# 12              EXPIRY_DATE     595
# 13               MODEL_YEAR      25
# 14                     MAKE      21
# 15                    MODEL     100
# 16                    COLOR      10
# 17         INITIAL_ODOMETER     949
# 18          LOW_MILEAGE_USE       2
# 19                   GENDER       2
# 20                BIRTHDATE     955
# 21   DRIVERS_LICENSE_EXPIRY     720
# 22  DATE_AT_CURRENT_ADDRESS     891
# 23         COMMUTE_DISCOUNT       2
# 24          EXPIRED_LICENSE     759
# 25            EXPIRED_CLAIM     463

# %%
df_claim[['LOSS_EVENT_TIME','MODEL_YEAR']].head()
# Out:
#   LOSS_EVENT_TIME  MODEL_YEAR
# 0      2017-04-25        2010
# 1      2018-08-26        2008
# 2      2016-01-07        2009
# 3      2016-12-11        2002
# 4      2017-06-06        2010

# %%
#older the cars, bigger the minus
df_claim['CAR_AGE'] = df_claim.MODEL_YEAR - df_claim.LOSS_EVENT_TIME.dt.year
df_claim['CAR_AGE'].head()
# Out:
# 0    -7
# 1   -10
# 2    -7
# 3   -14
# 4    -7
# Name: CAR_AGE, dtype: int64

# %%
#Y2K problems it realize 50, and think it 2050
df_claim[['LOSS_EVENT_TIME','BIRTHDATE']]
# Out:
#     LOSS_EVENT_TIME  BIRTHDATE
# 0        2017-04-25 1973-12-25
# 1        2018-08-26 2045-09-14
# 2        2016-01-07 1988-05-16
# 3        2016-12-11 1974-01-18
# 4        2017-06-06 2050-05-01
# ..              ...        ...
# 970      2016-11-29 1979-11-10
# 971      2016-08-14 2069-02-01
# 972      2016-08-22 2055-09-21
# 973      2017-01-24 2069-10-25
# 974      2016-07-05 1982-06-06
#
# [975 rows x 2 columns]

# %%
#So subtract LOSS_EVENT_TIME and	BIRTHDATE +100 if <0 else *1 
df_claim['CUSTOMER_AGE'] = df_claim.LOSS_EVENT_TIME.dt.year - df_claim.BIRTHDATE.dt.year 
df_claim['CUSTOMER_AGE']
# Out:
# 0      44
# 1     -27
# 2      28
# 3      42
# 4     -33
#        ..
# 970    37
# 971   -53
# 972   -39
# 973   -52
# 974    34
# Name: CUSTOMER_AGE, Length: 975, dtype: int64

# %%
df_claim['CUSTOMER_AGE'] = [q+100 if q<0 else q*1 for q in df_claim['CUSTOMER_AGE'].values ]
df_claim['CUSTOMER_AGE']
# Out:
# 0      44
# 1      73
# 2      28
# 3      42
# 4      67
#        ..
# 970    37
# 971    47
# 972    61
# 973    48
# 974    34
# Name: CUSTOMER_AGE, Length: 975, dtype: int64

# %%
#Lets think about ODOMETER, as bigger as more damage and could cause accident
df_claim[['ODOMETER_AT_LOSS','INITIAL_ODOMETER']].head()
# Out:
#    ODOMETER_AT_LOSS  INITIAL_ODOMETER
# 0          157654.9            144972
# 1          226154.5            212580
# 2           83968.6             77994
# 3          309570.3            296352
# 4          136633.9            134244

# %%
#Final ODOMETER
df_claim['FINAL_ODOMETER'] = df_claim.ODOMETER_AT_LOSS - df_claim.INITIAL_ODOMETER
df_claim['FINAL_ODOMETER']
# Out:
# 0      12682.9
# 1      13574.5
# 2       5974.6
# 3      13218.3
# 4       2389.9
#         ...
# 970     7022.7
# 971     5661.9
# 972     4640.1
# 973     5963.9
# 974    13736.2
# Name: FINAL_ODOMETER, Length: 975, dtype: float64

# %%
#And all value > 0
(df_claim['FINAL_ODOMETER'] < 0).value_counts()
# Out:
# False    975
# Name: FINAL_ODOMETER, dtype: int64

# %%
df_claim['ADRESS_YEAR'] = df_claim.LOSS_EVENT_TIME.dt.year - df_claim.DATE_AT_CURRENT_ADDRESS.dt.year
df_claim['ADRESS_YEAR'].head()
# Out:
# 0    18
# 1     7
# 2    11
# 3    16
# 4     5
# Name: ADRESS_YEAR, dtype: int64

# %%
df_claim[df_claim['ADRESS_YEAR'] < 0]
# Out:
#      INCIDENT_CAUSE  CLAIM_STATUS  ODOMETER_AT_LOSS LOSS_EVENT_TIME  \
# 43                3             1          241219.8      2016-04-27
# 64                2             3          149077.6      2016-11-08
# 65                5             1          325260.6      2016-09-28
# 71                2             1          371183.8      2016-08-26
# 141               3             3           68089.2      2016-03-18
# 169               1             1          383898.7      2016-03-29
# 179               5             1          102876.0      2016-10-09
# 186               1             3          243294.0      2016-05-08
# 220               2             1          114242.3      2016-09-10
# 296               2             1          290003.5      2016-06-14
# 309               2             3           50768.3      2016-11-12
# 515               5             1          141209.2      2016-01-18
# 587               3             1          158250.2      2016-04-15
# 624               1             1          173970.0      2016-02-26
# 732               5             1          152029.1      2016-05-01
# 735               1             3          252003.8      2016-12-21
# 810               4             1           44897.9      2016-02-27
# 820               2             3          301696.3      2016-08-11
# 906               3             3          422412.8      2016-11-05
# 951               1             1          172955.9      2016-01-11
#
#     CLAIM_INIT_TIME  POLICE_REPORT  CLAIMS_AT_LOSS_DATE  LOSS_LOCATION_LAT  \
# 43       2016-05-05              1                    3          41.867305
# 64       2016-11-08              0                    1          41.885797
# 65       2016-10-04              0                    1          41.891208
# 71       2016-09-01              1                    5          41.847148
# 141      2016-03-27              1                    1          41.750546
# 169      2016-04-06              0                    1          41.710281
# 179      2016-10-13              0                    1          41.985200
# 186      2016-05-14              0                    2          41.780599
# 220      2016-09-19              1                    4          41.881179
# 296      2016-06-16              0                    1          41.792911
# 309      2016-11-17              0                    1          41.959100
# 179             92100                0      F 1972-04-01
# 186            234936                0      M 2066-05-07
# 220            110016                1      M 2046-06-06
# 296            277056                0      F 1997-07-07
# 309             45600                0      M 2042-01-27
# 515            130824                0      F 2043-07-13
# 587            144672                0      M 2057-11-07
# 624            160800                0      M 1973-02-26
# 732            139320                0      M 2070-11-06
# 735            249744                0      M 1984-07-18
# 810             39744                0      M 1983-08-08
# 820            300612                0      M 2060-04-09
# 906            420960                0      F 1993-04-04
# 951            166968                0      M 2062-01-29
#
#     DRIVERS_LICENSE_EXPIRY DATE_AT_CURRENT_ADDRESS  COMMUTE_DISCOUNT  \
# 43              2019-01-07              2017-07-21                 0
# 64              2019-10-09              2017-09-25                 0
# 65              2021-05-10              2017-07-14                 0
# 71              2019-07-24              2017-03-23                 0
# 141             2021-09-10              2017-08-26                 1
# 169             2021-03-10              2017-07-12                 0
# 179             2021-04-20              2017-11-22                 0
# 186             2019-11-25              2017-05-26                 0
# 220             2020-05-30              2017-02-14                 0
# 296             2021-01-16              2017-05-19                 0
# 309             2019-10-11              2017-02-21                 0
# 515             2021-03-04              2017-09-19                 0
# 587             2018-06-06              2017-03-05                 0
# 624             2019-12-04              2017-01-20                 0
# 732             2019-02-12              2017-07-19                 0
# 735             2021-05-28              2017-07-17                 0
# 810             2020-11-27              2017-10-27                 0
# 820             2018-07-14              2017-11-22                 0
# 906             2019-07-21              2017-07-14                 1
# 951             2018-08-11              2017-02-04                 0
#
#      EXPIRED_LICENSE  EXPIRED_CLAIM  CAR_AGE  CUSTOMER_AGE  FINAL_ODOMETER  \
# 43               985            145      -12            80          7075.8
# 64              1065            -26       -6            45         12349.6
# 65              1685           -233      -16            52         11532.6
# 71              1062             37      -18            42           527.8
# 141             2002             83       -3            41          4189.2
# 169             1807            -70      -16            80          9306.7
# 179             1654            -51       -5            44         10776.0
# 186             1296            -84      -13            50          8358.0
# 220             1358            -27      -12            70          4226.3
# 296             1677             40      -12            19         12947.5
# 309             1063            -84       -2            74          5168.3
# 515             1872             93       -6            73         10385.2
# 587              782             30       -8            59         13578.2
# 624             1377            148       -8            43         13170.0
# 732             1017             61       -6            46         12709.1
# 735             1619            -63      -11            32          2259.8
# 810             1735             46       -2            33          5153.9
# 820              702             52      -13            56          1084.3
# 906              988           -235      -20            23          1452.8
# 951              943            142       -9            54          5987.9
#
#      ADRESS_YEAR
# 43            -1
# 64            -1
# 65            -1
# 71            -1
# 141           -1
# 169           -1
# 179           -1
# 186           -1
# 220           -1
# 296           -1
# 309           -1
# 515           -1
# 587           -1
# 624           -1
# 732           -1
# 735           -1
# 810           -1
# 820           -1
# 906           -1
# 951           -1

# %%
#drop -1 current addres
df_claim.drop(df_claim[df_claim['ADRESS_YEAR'] < 0].index, inplace=True)

# %%
df_claim['EXCESSIVE_CLAIM_AMOUNT'] = df_claim.CLAIM_AMOUNT.where(df_claim.CLAIM_AMOUNT < 10000).fillna(1)
df_claim['EXCESSIVE_CLAIM_AMOUNT']
# Out:
# 0         1.0
# 1      1909.0
# 2         1.0
# 3         1.0
# 4      2130.0
#         ...
# 970       1.0
# 971    2320.0
# 972       1.0
# 973    1720.0
# 974    1050.0
# Name: EXCESSIVE_CLAIM_AMOUNT, Length: 955, dtype: float64

# %%
df_claim['EXCESSIVE_CLAIM_AMOUNT'] = df_claim['EXCESSIVE_CLAIM_AMOUNT'].where(df_claim['EXCESSIVE_CLAIM_AMOUNT'] == 1.0).fillna(0)
df_claim['EXCESSIVE_CLAIM_AMOUNT']
# Out:
# 0      1.0
# 1      0.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 970    1.0
# 971    0.0
# 972    1.0
# 973    0.0
# 974    0.0
# Name: EXCESSIVE_CLAIM_AMOUNT, Length: 955, dtype: float64

# %%
#Lets drop some columns to reduce confuse
#CLAIM_STATUS = actually just status of the claim
#LOSS_LOCATION_LAT = no pattern in visualization
#LOSS_LOCATION_LONG = no pattern in visualization
#CLAIM_INIT_TIME = already subtracted with CLAIMS_AT_LOSS_DATE
#LOSS_EVENT_TIME = already used in DRIVERS_LICENSE_EXPIRY, BIRTHDATE, MODEL_YEAR, EXPIRY_DATE
#START_DATE = theres no useful information
#EXPIRY_DATE = already subtract in expired claim
#MODEL_YEAR = already subtracted in CAR_AGE
#ODOMETER_AT_LOSS = already subtractes in 'FINAL_ODOMETER'
#INITIAL_ODOMETER = already subtractes in 'FINAL_ODOMETER'
#GENDER = its almost 50:50
#BIRTHDATE = already subtracted in age
#DRIVERS_LICENSE_EXPIRY = already subtracted in license loss
#DATE_AT_CURRENT_ADDRESS = its already subtracted in ADRESS_YEAR
dropped = ['DATE_AT_CURRENT_ADDRESS', 'DRIVERS_LICENSE_EXPIRY', 'BIRTHDATE', 'GENDER', 'INITIAL_ODOMETER', \
          'ODOMETER_AT_LOSS', 'MODEL_YEAR', 'EXPIRY_DATE', 'START_DATE', 'LOSS_EVENT_TIME', \
          'CLAIM_INIT_TIME', 'LOSS_LOCATION_LONG', 'LOSS_LOCATION_LAT', 'CLAIM_STATUS' \
          ,'MAKE','MODEL','COLOR']

# %%
Xy = df_claim.drop(columns=dropped)
Xy
# Out:
#      INCIDENT_CAUSE  POLICE_REPORT  CLAIMS_AT_LOSS_DATE  CLAIM_AMOUNT  \
# 0                 3              1                    1       35765.0
# 1                 3              0                    1        1909.0
# 2                 1              0                    2       25730.0
# 3                 1              0                    1       40880.0
# 4                 3              0                    1        2130.0
# ..              ...            ...                  ...           ...
# 970               3              1                    1       44666.0
# 971               1              0                    1        2320.0
# 972               1              1                    1       39307.0
# 973               2              0                    1        1720.0
# 974               2              1                    1        1050.0
#
#      FLAG_FOR_FRAUD_INV  LOW_MILEAGE_USE  COMMUTE_DISCOUNT  EXPIRED_LICENSE  \
# 0                     1                0                 0              481
# 1                     0                0                 0             -211
# 2                     1                1                 0             1412
# 3                     1                0                 0              886
# 4                     0                0                 0             1126
# ..                  ...              ...               ...              ...
# 970                   1                0                 0              571
# 971                   0                0                 0             1097
# 972                   1                0                 1             1219
# 973                   0                0                 0             1332
# 974                   0                0                 0             1478
#
#      EXPIRED_CLAIM  CAR_AGE  CUSTOMER_AGE  FINAL_ODOMETER  ADRESS_YEAR  \
# 0              147       -7            44         12682.9           18
# 1              -73      -10            73         13574.5            7
# 2              229       -7            28          5974.6           11
# 3             -140      -14            42         13218.3           16
# 4             -150       -7            67          2389.9            5
# ..             ...      ...           ...             ...          ...
# 970           -141       -3            37          7022.7            1
# 971            -25       -9            47          5661.9            2
# 972             -2      -10            61          4640.1            2
# 973             87      -14            48          5963.9            7
# 974           -177       -9            34         13736.2           13
#
#      EXCESSIVE_CLAIM_AMOUNT
# 0                       1.0
# 1                       0.0
# 2                       1.0
# 3                       1.0
# 4                       0.0
# ..                      ...
# 970                     1.0
# 971                     0.0
# 972                     1.0
# 973                     0.0
# 974                     0.0
#
# [955 rows x 14 columns]

# %%
for i in Xy.columns.to_list():
    sns.boxplot(Xy[i])
    plt.show()

# %%
#Outliers still exist! lets treat it
Q1 = Xy.quantile(0.25)
Q3 = Xy.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# INCIDENT_CAUSE                3.0
# POLICE_REPORT                 1.0
# CLAIMS_AT_LOSS_DATE           1.0
# CLAIM_AMOUNT              22405.0
# FLAG_FOR_FRAUD_INV            1.0
# LOW_MILEAGE_USE               0.0
# COMMUTE_DISCOUNT              0.0
# EXPIRED_LICENSE             718.5
# EXPIRED_CLAIM               199.0
# CAR_AGE                       6.0
# CUSTOMER_AGE                 33.0
# FINAL_ODOMETER             7065.8
# ADRESS_YEAR                   9.0
# EXCESSIVE_CLAIM_AMOUNT        1.0
# dtype: float64

# %%
dataset_cleared = Xy[~((Xy < (Q1 - 1.5 * IQR)) |(Xy > (Q3 + 1.5 * IQR))).any(axis=1)]
dataset_cleared
# Out:
#      INCIDENT_CAUSE  POLICE_REPORT  CLAIMS_AT_LOSS_DATE  CLAIM_AMOUNT  \
# 0                 3              1                    1       35765.0
# 1                 3              0                    1        1909.0
# 3                 1              0                    1       40880.0
# 4                 3              0                    1        2130.0
# 5                 1              0                    1        1970.0
# ..              ...            ...                  ...           ...
# 969               3              1                    1        2440.0
# 970               3              1                    1       44666.0
# 971               1              0                    1        2320.0
# 973               2              0                    1        1720.0
# 974               2              1                    1        1050.0
#
#      FLAG_FOR_FRAUD_INV  LOW_MILEAGE_USE  COMMUTE_DISCOUNT  EXPIRED_LICENSE  \
# 0                     1                0                 0              481
# 1                     0                0                 0             -211
# 3                     1                0                 0              886
# 4                     0                0                 0             1126
# 5                     0                0                 0             1300
# ..                  ...              ...               ...              ...
# 969                   0                0                 0              896
# 970                   1                0                 0              571
# 971                   0                0                 0             1097
# 973                   0                0                 0             1332
# 974                   0                0                 0             1478
#
#      EXPIRED_CLAIM  CAR_AGE  CUSTOMER_AGE  FINAL_ODOMETER  ADRESS_YEAR  \
# 0              147       -7            44         12682.9           18
# 1              -73      -10            73         13574.5            7
# 3             -140      -14            42         13218.3           16
# 4             -150       -7            67          2389.9            5
# 5              -50      -14            22          9666.1           17
# ..             ...      ...           ...             ...          ...
# 969            134      -13            68          3673.9            4
# 970           -141       -3            37          7022.7            1
# 971            -25       -9            47          5661.9            2
# 973             87      -14            48          5963.9            7
# 974           -177       -9            34         13736.2           13
#
#      EXCESSIVE_CLAIM_AMOUNT
# 0                       1.0
# 1                       0.0
# 3                       1.0
# 4                       0.0
# 5                       0.0
# ..                      ...
# 969                     0.0
# 970                     1.0
# 971                     0.0
# 973                     0.0
# 974                     0.0
#
# [729 rows x 14 columns]

# %%
df_zscore = (dataset_cleared - dataset_cleared.mean()) / dataset_cleared.std()
df_zscore
# Out:
#      INCIDENT_CAUSE  POLICE_REPORT  CLAIMS_AT_LOSS_DATE  CLAIM_AMOUNT  \
# 0          0.000905       1.152064            -0.468085      1.692009
# 1          0.000905      -0.866817            -0.468085     -0.772654
# 3         -1.319197      -0.866817            -0.468085      2.064373
# 4          0.000905      -0.866817            -0.468085     -0.756565
# 5         -1.319197      -0.866817            -0.468085     -0.768213
# ..              ...            ...                  ...           ...
# 969        0.000905       1.152064            -0.468085     -0.733998
# 970        0.000905       1.152064            -0.468085      2.339988
# 971       -1.319197      -0.866817            -0.468085     -0.742734
# 973       -0.659146      -0.866817            -0.468085     -0.786413
# 974       -0.659146       1.152064            -0.468085     -0.835188
#
#      FLAG_FOR_FRAUD_INV  LOW_MILEAGE_USE  COMMUTE_DISCOUNT  EXPIRED_LICENSE  \
# 0              1.229519              NaN               NaN        -0.799005
# 1             -0.812211              NaN               NaN        -2.143019
# 3              1.229519              NaN               NaN        -0.012407
# 4             -0.812211              NaN               NaN         0.453725
# 5             -0.812211              NaN               NaN         0.791671
# ..                  ...              ...               ...              ...
# 969           -0.812211              NaN               NaN         0.007015
# 970            1.229519              NaN               NaN        -0.624206
# 971           -0.812211              NaN               NaN         0.397401
# 973           -0.812211              NaN               NaN         0.853821
# 974           -0.812211              NaN               NaN         1.137385
#
#      EXPIRED_CLAIM   CAR_AGE  CUSTOMER_AGE  FINAL_ODOMETER  ADRESS_YEAR  \
# 0         1.096782  0.297951     -0.265246        1.186774     1.587790
# 1        -0.437282 -0.391593      1.250722        1.399458    -0.438063
# 3        -0.904474 -1.310986     -0.369796        1.314489     1.219453
# 4        -0.974204  0.297951      0.937073       -1.268533    -0.806400
# 5        -0.276902 -1.310986     -1.415291        0.467142     1.403622
# ..             ...       ...           ...             ...          ...
# 969       1.006132 -1.081138      0.989348       -0.962246    -0.990569
# 970      -0.911447  1.217344     -0.631169       -0.163418    -1.543074
# 971      -0.102577 -0.161745     -0.108422       -0.488025    -1.358906
# 973       0.678401 -1.310986     -0.056147       -0.415986    -0.438063
# 974      -1.162475 -0.161745     -0.787994        1.438030     0.666948
#
#      EXCESSIVE_CLAIM_AMOUNT
# 0                  1.212093
# 1                 -0.823888
# 3                  1.212093
# 4                 -0.823888
# 5                 -0.823888
# ..                      ...
# 969               -0.823888
# 970                1.212093
# 971               -0.823888
# 973               -0.823888
# 974               -0.823888
#
# [729 rows x 14 columns]

# %%
dataset_cleared[df_zscore > 3].count()
# Out:
# INCIDENT_CAUSE            0
# POLICE_REPORT             0
# CLAIMS_AT_LOSS_DATE       0
# CLAIM_AMOUNT              0
# FLAG_FOR_FRAUD_INV        0
# LOW_MILEAGE_USE           0
# COMMUTE_DISCOUNT          0
# EXPIRED_LICENSE           0
# EXPIRED_CLAIM             0
# CAR_AGE                   0
# CUSTOMER_AGE              0
# FINAL_ODOMETER            0
# ADRESS_YEAR               0
# EXCESSIVE_CLAIM_AMOUNT    0
# dtype: int64

# %%
dataset_cleared[df_zscore < -3].count()
# Out:
# INCIDENT_CAUSE            0
# POLICE_REPORT             0
# CLAIMS_AT_LOSS_DATE       0
# CLAIM_AMOUNT              0
# FLAG_FOR_FRAUD_INV        0
# LOW_MILEAGE_USE           0
# COMMUTE_DISCOUNT          0
# EXPIRED_LICENSE           0
# EXPIRED_CLAIM             0
# CAR_AGE                   0
# CUSTOMER_AGE              0
# FINAL_ODOMETER            0
# ADRESS_YEAR               0
# EXCESSIVE_CLAIM_AMOUNT    0
# dtype: int64

# %%
for j in dataset_cleared.columns.to_list():
    sns.boxplot(dataset_cleared[j])
    plt.show()

# %%
X = dataset_cleared.drop(columns='FLAG_FOR_FRAUD_INV')
y = dataset_cleared.FLAG_FOR_FRAUD_INV

# %%
#Importing modules
#Prepocessing
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split

#Algorithm
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
#Neural Network
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

#Pipeline and Cross Validation
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

#Model Evaluation
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_confusion_matrix

#import time
from datetime import datetime

# %%
train_test_size = np.array([0.4, 0.3, 0.25, 0.2])

# %%
#with this, data can be used with same data to all algorithm without generating more than once
def train_test_function(X,y, test_size, random_state=42):
    return train_test_split(X,y, test_size=test_size, random_state=random_state)

# %%
#return rules [0] = X_train, [1] = X_test, [2] = y_train, [3] = y_test
data60 = train_test_function(X,y, 0.4)
data70 = train_test_function(X,y, 0.3)
data75 = train_test_function(X,y, 0.25)
data80 = train_test_function(X,y, 0.2)

# %%
def hyper_dt():
    #Pipeline
    pipe_dt = Pipeline(steps=[('scaler', StandardScaler()), ('DT', DecisionTreeClassifier())])
    # Parameter Tuning
    param_dist_dt = {"DT__criterion": ['gini', 'entropy'], "DT__max_depth": [None, 6, 10, 20, 50]}
    model = GridSearchCV(pipe_dt, param_grid=param_dist_dt, cv = 5, n_jobs=-1)
    return model

# %%
def fit_data(model, data):
    XTRAIN, XTEST, YTRAIN, YTEST = data
    model.fit(XTRAIN, YTRAIN)
    return model

# %%
def predict_data(model, data):
    XTRAIN, XTEST, YTRAIN, YTEST = data
    test_acc = accuracy_score(YTEST, model.predict(XTEST))
    training_acc = accuracy_score(YTRAIN, (model.predict(XTRAIN)))
    return (training_acc, test_acc, )

# %%
print('Start : ', datetime.now())
dt_fit = fit_data(hyper_dt(), data75)
print('End   :', datetime.now())
# Out:
# Start :  2021-01-23 22:08:29.941809
# End   : 2021-01-23 22:08:30.153215

# %%
dt_fit.best_params_
# Out:
# {'DT__criterion': 'gini', 'DT__max_depth': None}

# %%
dt60 = predict_data(dt_fit, data60)
dt70 = predict_data(dt_fit, data70)
dt75 = predict_data(dt_fit, data75)
dt80 = predict_data(dt_fit, data80)

# %%
def hyper_logreg():
    #Pipeline
    pipe_logreg = Pipeline(steps=[('scaler', StandardScaler()), ('logreg', LogisticRegression())])
    # Parameter Tuning
    param_dist_logreg = {'logreg__C':[1.0, 0.1, 0.01, 0.001], 
                 'logreg__solver':['newton-cg', 'lbfgs', 'liblinear'],
                  'logreg__max_iter':[100, 1000]
                 }
    
    model = GridSearchCV(pipe_logreg, param_grid=param_dist_logreg, cv = 5, n_jobs=-1)
    return model

# %%
print('Start :', datetime.now())
logreg_fit = fit_data(hyper_logreg(), data75)
print('End   :', datetime.now())
# Out:
# Start : 2021-01-23 22:12:12.015598
# End   : 2021-01-23 22:12:12.462319

# %%
logreg_fit.best_params_
# Out:
# {'logreg__C': 1.0, 'logreg__max_iter': 100, 'logreg__solver': 'newton-cg'}

# %%
logreg60 = predict_data(logreg_fit, data60)
logreg70 = predict_data(logreg_fit, data70)
logreg75 = predict_data(logreg_fit, data75)
logreg80 = predict_data(logreg_fit, data80)

# %%
def hyper_svm():
    #Pipeline
    pipe_svm = Pipeline(steps=[('scaler', StandardScaler()), ('svm', svm.SVC())])
    # Parameter Tuning
    param_dist_svm = {'svm__C':[1.0, 0.1, 0.01, 0.001], 'svm__gamma':[1,0.1,0.01], 'svm__kernel': ['rbf', 'poly', 'sigmoid']}
                 
    
    model = GridSearchCV(pipe_svm, param_grid=param_dist_svm, cv = 5, n_jobs=-1)
    return model

# %%
print('Start :', datetime.now())
svm_fit = fit_data(hyper_svm(), data75)
print('End   :', datetime.now())
# Out:
# Start : 2021-01-23 22:14:33.069973
# End   : 2021-01-23 22:14:33.731561

# %%
svm_fit.best_params_
# Out:
# {'svm__C': 1.0, 'svm__gamma': 0.1, 'svm__kernel': 'rbf'}

# %%
svm60 = predict_data(svm_fit, data60)
svm70 = predict_data(svm_fit, data70)
svm75 = predict_data(svm_fit, data75)
svm80 = predict_data(svm_fit, data80)

# %%
pd.DataFrame({'Training':[svm60[5], svm70[5], svm75[5], svm80[5]], 'Testing':[svm60[6], svm70[6], svm75[6], svm80[6]]})
# Out:
#    Training   Testing
# 0  0.972540  0.972544
# 1  0.966667  0.966667
# 2  0.965201  0.965188
# 3  0.963979  0.964029

# %%
def hyper_knn():
    #Pipeline
    pipe_knn = Pipeline(steps=[('scaler', StandardScaler()), ('knn', KNeighborsClassifier())])
    # Parameter Tuning
    param_dist_knn = {'knn__leaf_size':[30, 40, 50, 70, 100], 'knn__n_neighbors':list(range(1,100)), 'knn__weights': ['uniform', 'distance']}
                 
    
    model = GridSearchCV(pipe_knn, param_grid=param_dist_knn, cv = 5, n_jobs=-1)
    return model

# %%
print('Start :', datetime.now())
knn_fit = fit_data(hyper_knn(), data75)
print('End   :', datetime.now())
# Out:
# Start : 2021-01-23 22:18:15.672391
# End   : 2021-01-23 22:18:35.903406

# %%
knn_fit.best_params_
# Out:
# {'knn__leaf_size': 30, 'knn__n_neighbors': 31, 'knn__weights': 'uniform'}

# %%
knn60 = predict_data(knn_fit, data60)
knn70 = predict_data(knn_fit, data70)
knn75 = predict_data(knn_fit, data75)
knn80 = predict_data(knn_fit, data80)

# %%
def hyper_rf():
    #Pipeline
    pipe_rf = Pipeline(steps=[('scaler', StandardScaler()), ('rf', RandomForestClassifier())])
    # Parameter Tuning
    param_dist_rf = {"rf__max_depth": [6, 10, 20, 50], "rf__n_estimators": np.array([100, 250, 200, 500]), \
                  'rf__criterion': ['gini', 'entropy']}
    
    model = GridSearchCV(pipe_rf, param_grid=param_dist_rf, cv = 5, n_jobs=-1)
    return model

# %%
print('Start :', datetime.now())
rf_fit = fit_data(hyper_rf(), data75)
print('End   :', datetime.now())
# Out:
# Start : 2021-01-23 22:24:52.989992
# End   : 2021-01-23 22:25:22.281843

# %%
rf_fit.best_params_
# Out:
# {'rf__criterion': 'gini', 'rf__max_depth': 10, 'rf__n_estimators': 100}

# %%
rf60 = predict_data(rf_fit, data60)
rf70 = predict_data(rf_fit, data70)
rf75 = predict_data(rf_fit, data75)
rf80 = predict_data(rf_fit, data80)

# %%
def hyper_xgb():
    #Pipeline
    pipe = Pipeline(steps=[('scaler', StandardScaler()), ('XGB', XGBClassifier())])
    # Parameter Tuning
    param_dist = {"XGB__max_depth": [6, 10, 20, 50], "XGB__n_estimators": [100, 250, 200, 500], "XGB__learning_rate": [0.1, 0.01]}
    
    model = GridSearchCV(pipe, param_grid=param_dist, cv = 5, n_jobs=-1)
    return model

# %%
print('Start :', datetime.now())
xgb_fit = fit_data(hyper_xgb(), data75)
print('End   :', datetime.now())
# Out:
# Start : 2021-01-23 22:25:22.313822
# [22:25:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# End   : 2021-01-23 22:25:43.469095
# C:\Users\Jey\anaconda3\lib\site-packages\xgboost\sklearn.py:892: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
xgb_fit_fit.best_params_
# Out:
# {'XGB__learning_rate': 0.1, 'XGB__max_depth': 6, 'XGB__n_estimators': 100}

# %%
xgb60 = predict_data(xgb_fit, data60)
xgb70 = predict_data(xgb_fit, data70)
xgb75 = predict_data(xgb_fit, data75)
xgb80 = predict_data(xgb_fit, data80)

# %%
#Neural Network
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical 
from keras.wrappers.scikit_learn import KerasClassifier

#Try with neural Network
# baseline model
def create_baseline():
    # create model
    model = Sequential()
    model.add(Dense(13, input_shape = (13,), activation='relu'))
    model.add(Dense(13, activation='relu'))
    model.add(Dense(2, activation='softmax'))
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model
# Out:
# Using TensorFlow backend.

# %%
def hyper_nn(data):
    model = KerasClassifier(build_fn=create_baseline)
    params = {'nn__epochs':[10, 20, 50, 100], 'nn__batch_size':[10, 32, 64, 100]}
    pipe = Pipeline(steps=[('scaler', StandardScaler()), ('nn', model)])
    grid_search = GridSearchCV(pipe, param_grid=params, cv =5)
    XTRAIN, XTEST, YTRAIN, YTEST = data   
    grid_search.fit(XTRAIN, to_categorical(YTRAIN))
    
    return grid_search

# %%
nn_fit = hyper_nn(data75)
# Out:
# WARNING:tensorflow:From C:\Users\Jey\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
#
# Epoch 47/50
# 546/546 [==============================] - 0s 51us/step - loss: 0.0780 - accuracy: 0.9780
# Epoch 48/50
# 546/546 [==============================] - 0s 49us/step - loss: 0.0772 - accuracy: 0.9780
# Epoch 49/50
# 546/546 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.97 - 0s 53us/step - loss: 0.0763 - accuracy: 0.9780
# Epoch 50/50
# 546/546 [==============================] - 0s 49us/step - loss: 0.0755 - accuracy: 0.9780

# %%
nn60 = predict_data(nn_fit, data60)
nn70 = predict_data(nn_fit, data70)
nn75 = predict_data(nn_fit, data75)
nn80 = predict_data(nn_fit, data80)

# %%
cols = ['Algorithm', 'Best_Parameters', 'Accuracy_Training_60', 'Accuracy_Testing_60', \
        'Accuracy_Training_70', 'Accuracy_Testing_70', 'Accuracy_Training_75', 'Accuracy_Testing_75', \
        'Accuracy_Training_80', 'Accuracy_Testing_80']

# %%
def to_df(*res):
    c = []
    for a in res:
        for b in a:
            c.append(b)
    
    return  pd.DataFrame([c], columns=cols)

# %%
df_lr = to_df(['Logistic Regression'], [logreg_fit.best_params_], logreg60, logreg70, logreg75, logreg80)
df_dt = to_df(['Decision Tree'], [dt_fit.best_params_], dt60, dt70, dt75, dt80)
df_svm = to_df(['Support Vector Machine'], [svm_fit.best_params_], svm60, svm70, svm75, svm80)
df_knn = to_df(['K-Nearest Neighbor'], [knn_fit.best_params_], knn60, knn70, knn75, knn80)
df_rf = to_df(['Random Forest'], [rf_fit.best_params_], rf60, rf70, rf75, rf80)
df_xgb = to_df(['Xtreme Gradient Boost'], [xgb_fit.best_params_], xgb60, xgb70, xgb75, xgb80)
df_nn = to_df(['Neural Network Keras'], [nn_fit.best_params_], nn60, nn70, nn75, nn80)

# %%
df_results = pd.concat([df_lr, df_dt, df_svm, df_knn, df_rf, df_xgb, df_nn], ignore_index = True)
df_results
# Out:
#                 Algorithm                                    Best_Parameters  \
# 0     Logistic Regression  {'logreg__C': 1.0, 'logreg__max_iter': 100, 'l...
# 1           Decision Tree   {'DT__criterion': 'gini', 'DT__max_depth': None}
# 2  Support Vector Machine  {'svm__C': 1.0, 'svm__gamma': 0.1, 'svm__kerne...
# 3      K-Nearest Neighbor  {'knn__leaf_size': 30, 'knn__n_neighbors': 31,...
# 4           Random Forest  {'rf__criterion': 'gini', 'rf__max_depth': 50,...
# 5   Xtreme Gradient Boost  {'XGB__learning_rate': 0.1, 'XGB__max_depth': ...
# 6    Neural Network Keras          {'nn__batch_size': 100, 'nn__epochs': 50}
#
#    Accuracy_Training_60  Accuracy_Testing_60  Accuracy_Training_70  \
# 0              0.981693             0.958904              0.980392
# 1              1.000000             0.969178              1.000000
# 2              0.977117             0.955479              0.976471
# 3              0.981693             0.955479              0.980392
# 4              1.000000             0.972603              1.000000
# 5              0.997712             0.979452              0.998039
# 6              0.979405             0.962329              0.978431
#
#    Accuracy_Testing_70  Accuracy_Training_75  Accuracy_Testing_75  \
# 0             0.954338              0.976190             0.961749
# 1             0.958904              1.000000             0.950820
# 2             0.949772              0.972527             0.956284
# 3             0.949772              0.976190             0.956284
# 4             0.963470              1.000000             0.956284
# 5             0.972603              0.998168             0.967213
# 6             0.958904              0.978022             0.956284
#
#    Accuracy_Training_80  Accuracy_Testing_80
# 0              0.974271             0.965753
# 1              0.998285             0.945205
# 2              0.970840             0.958904
# 3              0.974271             0.958904
# 4              0.996569             0.958904
# 5              0.996569             0.965753
# 6              0.975986             0.958904

# %%
train_test_size = np.array([0.4, 0.3, 0.25, 0.2])
def plotting(alg, train_result, test_results, train_test_size):
    sns.set_style('darkgrid')
    sns.lineplot(1-train_test_size, train_result, label='Training')
    sns.lineplot(1-train_test_size, test_results, label='Testing')
    plt.xlabel('Data Size')
    plt.ylabel('Accuracy')
    plt.title(alg)
    plt.legend()
    plt.show()

# %%
plotting('Xtreme Gradient Boost with Hyperparameter Tuning', [xgb60[0], xgb70[0], xgb75[0], xgb80[0]], [xgb60[1],\
        xgb70[1], xgb75[1], xgb80[1]], train_test_size)
plotting('Logistic Regression with Hyperparameter Tuning', [logreg60[0], logreg70[0], logreg75[0], logreg80[0]], [logreg60[1],\
        logreg70[1], logreg75[1], logreg80[1]], train_test_size)
plotting('Decision Tree with Hyperparameter Tuning', [dt60[0], dt70[0], dt75[0], dt80[0]], \
         [dt60[1],dt70[1], dt75[1], dt80[1]], train_test_size)
plotting('Random Forest with Hyperparameter Tuning', [rf60[0], rf70[0], rf75[0], rf80[0]], \
         [rf60[1],rf70[1], rf75[1], rf80[1]], train_test_size)
plotting('SVM with Hyperparameter Tuning', [svm60[0], svm70[0], svm75[0], svm80[0]], \
         [svm60[1], svm70[1], svm75[1], svm80[1]], train_test_size)
plotting('K-Nearest Neighbor with Hyperparameter Tuning', [knn60[0], knn70[0], knn75[0], knn80[0]], \
         [knn60[1], knn70[1], knn75[1], knn80[1]], train_test_size)
plotting('Neural Network with Keras', [nn60[0], nn70[0], nn75[0], nn80[0]], \
         [nn60[1], nn70[1], nn75[1], nn80[1]], train_test_size)

# %%
#Joined Accuarcy
sns.lineplot(x = 1-train_test_size, y = [logreg60[1], logreg70[1], logreg75[1], logreg80[1]], label = 'Linear Regression')
sns.lineplot(x = 1-train_test_size, y= [dt60[1],dt70[1], dt75[1], dt80[1]], label= 'Decision Tree Regression')
sns.lineplot(x = 1-train_test_size, y=[rf60[1], rf70[1], rf75[1], rf80[1]], label='Random Forest')
sns.lineplot(x = 1-train_test_size, y=[svm60[1],svm70[1], svm75[1], svm80[1]], label='Support Vector Machine')
sns.lineplot(x = 1-train_test_size, y=[knn60[1],knn70[1], knn75[1], knn80[1]], label='K-Nearest Neighbor')
sns.lineplot(x = 1-train_test_size, y=[xgb60[1], xgb70[1], xgb75[1], xgb80[1]], label='Xtreme Gradient Boost')
sns.lineplot(x = 1-train_test_size, y=[nn60[1],nn70[1], nn75[1], nn80[1]], label='Neural Network')
plt.legend()
plt.title('Accuracy Comparison on Testing Data')
plt.xlabel('Data Size')
plt.ylabel('Accuracyy')
plt.show()

# %%
#ROC Curve
fpr_xgb, tpr_xgb, t1 = roc_curve(data75[3], (xgb_fit.predict(data75[1])))
fpr_logreg, tpr_logreg, t2 = roc_curve(data75[3], (logreg_fit.predict(data75[1])))
fpr_dt, tpr_dt, t3 = roc_curve(data75[3], (dt_fit.predict(data75[1])))
fpr_rf, tpr_rf, t4 = roc_curve(data75[3], (rf_fit.predict(data75[1])))
fpr_knn, tpr_knn, t5 = roc_curve(data75[3], (knn_fit.predict(data75[1])))
fpr_svm, tpr_svm, t6 = roc_curve(data75[3], (svm_fit.predict(data75[1])))
fpr_nn, tpr_nn, t7 = roc_curve(data75[3], (nn_fit.predict(data75[1])))

# %%
#Plotting ROC AUC
#AUC can be computed using the trapezoidal rule. In general, an AUC of 0.5 suggests no discrimination (i.e., ability to diagnose patients with and without the disease or condition based on the test), 0.7 to 0.8 is considered acceptable, 0.8 to 0.9 is considered excellent, and more than 0.9 is considered outstanding.
plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr_xgb, tpr_xgb, label='Xtreme Gradient Boost', color = 'navy')
plt.plot(fpr_logreg, tpr_logreg, label='Logistic Regression', color= 'red')
plt.plot(fpr_dt, tpr_dt, label='Decision Tree', color='green')
plt.plot(fpr_rf, tpr_rf, label='Random Forest', color='gold')
plt.plot(fpr_knn, tpr_knn, label='K-Nearest Neighbor', color='brown')
plt.plot(fpr_svm, tpr_svm, label='Support Vector Machine', color='orange')
plt.plot(fpr_nn, tpr_nn, label='Neural Network with Tensorflow', color='blue')
plt.legend()
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %%
#Let use Neural Network
pd.DataFrame(classification_report(data75[3], nn_fit.predict(data75[1]), output_dict=True))
# Out:
#                     0          1  accuracy   macro avg  weighted avg
# precision    0.969388   0.941176  0.956284    0.955282      0.956592
# recall       0.950000   0.963855  0.956284    0.956928      0.956284
# f1-score     0.959596   0.952381  0.956284    0.955988      0.956324
# support    100.000000  83.000000  0.956284  183.000000    183.000000

# %%
# %matplotlib inline
sns.set_style('dark')
algo = [logreg_fit, dt_fit, svm_fit, knn_fit, rf_fit, xgb_fit, nn_fit]
algo_title = ['Logistic Regression', 'Decision Tree', 'Support Vector Machine', 'KNearest Neighbor', 'Random Forest'\
             'Xtreme Gradient Boost', 'Neural Network']
for p,q in zip(algo, algo_title) :
    plot_confusion_matrix(p, data75[1], data75[3] ,cmap=plt.cm.Blues )
    plt.title(q)

# %% [markdown]
# After did some deep analysis, in Data Understanding step, Data that used here is from insurance claim and is relatively small. in Data Preparation step, Data need to be converted in actual data type especially date type. in Feature Engineering step some of data need to clasify where are fraud or not fraud based especially on date claim, license, expired claim and claim amount and data need to be cleaned from outliers too. In modelling step using machine learning with hyperparemeter tuning, the result is using SVM perform better in this dataset than any other algorithm that I used here (XGB, Decision Tree, KNN, Logistic Regression, Random Forest and even Neural Network) and all of the accuracy results is a little different in each algorithm. I choose Neural Network because accuracy plot from training and testing was very stable and also conusion matrix tells false possitive and false negative is the least, and testing give accuracy 0.966. from ROC, all of algorithm get almost 1.
